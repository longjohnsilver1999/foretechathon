# %% [markdown]
# # RestructAI — MSME Credit-Risk EDA
# This notebook is a lightweight exploration companion. The reproducible report charts are generated by `src/evaluate_models.py`.

# %%
from pathlib import Path
import pandas as pd

project = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
data = pd.read_csv(project / 'data' / 'synthetic_msme_data.csv')
data.shape, data['default_90d'].mean()

# %%
data.groupby('industry')['default_90d'].agg(['count', 'mean']).sort_values('mean', ascending=False)
